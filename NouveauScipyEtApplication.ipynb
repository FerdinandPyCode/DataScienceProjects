# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(0,100,30)
y=np.linspace(0,200,30)
plt.scatter(x,y,c='blue',label='Courbe 1')
plt.scatter(y,x,c='green',label='Courbe 2')
plt.title('Ma courbe 2')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
x=np.linspace(0,2,100)
y=1/3*x**3 -3/5*x**2+2+np.random.randn(x.shape[0])/20
plt.scatter(x,y)

# %%
def f(x,a,b,c,d):
    return(a*x**3+b*x**2+c*x+d)

from scipy import optimize
params,param_cov=optimize.curve_fit(f,x,y)
plt.scatter(x,y)
plt.plot(x,f(x,params[0],params[1],params[2],params[3]),c='g',lw=3)
plt.show()

# %%
def f(x):
    return x**2+ 15*np.sin(x)
x=np.linspace(-10,10,100)
plt.plot(x,f(x))

# %%
optimize.minimize(f,x0=-5)
# Out:
#       fun: -12.823616887804443
#  hess_inv: array([[0.05978682]])
#       jac: array([3.57627869e-06])
#   message: 'Optimization terminated successfully.'
#      nfev: 18
#       nit: 4
#      njev: 9
#    status: 0
#   success: True
#         x: array([-1.38505584])

# %%
def f(x):
    return np.sin(x[0])+np.cos(x[0]+x[1])*np.cos(x[0])

# %%
x=np.linspace(-3,3,100)
y=np.linspace(-3,3,100)
x,y=np.meshgrid(x,y)
plt.contour(x,y,f(np.array([x,y])),20)
x0=np.zeros((2,1))

plt.scatter(x0[0],x0[1],marker='+',c='r',s=100)
result=optimize.minimize(f,x0=x0).x
plt.scatter(result[0],result[1],c='g',s=100)
print(result)
# Out:
# [-0.78539917 -2.35619341]

# %%
x0=np.zeros((2,1))

plt.scatter(x0[0],x0[1],marker='+',c='r',s=100)

# %%
x=np.linspace(0,20,100)
y=x+4*np.sin(x)+ np.random.randn(x.shape[0])
plt.plot(x,y)

# %%
from scipy import signal
new_y=signal.detrend(y)
plt.plot(x,y)
plt.plot(x,new_y)

# %%
x=np.linspace(0,30,1000)
y=3*np.sin(x)+2*np.sin(5*x)+np.sin(10*x)+np.random.random(x.shape[0])*10
plt.plot(x,y)

# %%
from scipy import fftpack
fourier=fftpack.fft(y)
pow=np.abs(fourier)
frequences=fftpack.fftfreq(y.size)
plt.plot(np.abs(frequences),pow)

# %%
fourier[pow<400]=0
plt.plot(np.abs(frequences),np.abs(fourier))

# %%
filterS=fftpack.ifft(fourier)
plt.figure(figsize=(12,8))
plt.plot(x,y,lw=0.5)
plt.plot(x,filterS,lw=3)
plt.show()
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1289: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
from scipy import ndimage
np.random.seed(0)
x=np.zeros((32,32))
x[10:-10,10:-10]=1
x[np.random.randint(0,32,30),np.random.randint(0,32,30)]=1
plt.imshow(x)

# %%
open_x=ndimage.binary_opening(x)
plt.imshow(open_x)
