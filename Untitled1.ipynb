# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %history
# Out:
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# bitcoin=pd.read_csv('BTC-EUR.csv')
# bitcoin=pd.read_csv('BTC-EUR.csv')
# bitcoin
# bitcoin.head()
# bitcoin['close'].plot(figsize=(9,6))
# bitcoin
# bitcoin['Close'].plot(figsize=(9,6))
# %history

# %%
bitcoin=pd.read_csv('BTC-EUR.csv',index_col='Date',parse_dates=True)

# %%
bitcoin['Close'].plot(figsize=(9,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
bitcoin.loc['2019-09','Close'].resample('5D').plot()
# Out:
# Date
# 2019-09-01    AxesSubplot(0.125,0.125;0.775x0.755)
# 2019-09-06    AxesSubplot(0.125,0.125;0.775x0.755)
# 2019-09-11    AxesSubplot(0.125,0.125;0.775x0.755)
# 2019-09-16    AxesSubplot(0.125,0.125;0.775x0.755)
# 2019-09-21    AxesSubplot(0.125,0.125;0.775x0.755)
# 2019-09-26    AxesSubplot(0.125,0.125;0.775x0.755)
# Freq: 5D, Name: Close, dtype: object

# %%
bitcoin.loc['2019','Close'].resample('M').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>
